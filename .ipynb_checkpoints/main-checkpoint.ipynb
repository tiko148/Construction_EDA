# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import chart_studio.plotly as py
import seaborn as sns
import plotly.express as px
import cufflinks as cf
# %matplotlib inline
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
#init_notebook_mode(connected = True)
cf.go_offline()
import plotly.graph_objects as go
from pandas.plotting import autocorrelation_plot
import datetime
from plotly.subplots import make_subplots
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
'''Setting option for pandas to show maximum rows and columns'''

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
'''


Below are the cleaned datasets that will be used for data visualization:


File 1 --> 'new_price_by_region' --> new houses sold in 4 regions based on price range of homes.
File 2 --> 'auth_not_started.csv' --> authorized permits but not yet started homes. 
File 3 --> 'sold_finance_type.csv' -- > the type if financing for a loan and the rate of change.
File 4 --> houses_sold_by_sales_price_USA.csv' -->New Houses sold in the USA based on price range.
File 5 --> 'construction_status_2021.csv' --> Construction status in the usa and regions in 2021. The status categories 
are [started, completed, under construction]. 

'''



#File 1
auth_not_started = pd.read_csv('auth_not_started.csv',index_col=0)

#File 2
new_price_by_region = pd.read_csv('new_price_by_region', index_col=0)

#File 3
sold_finance_type =  pd.read_csv('sold_finance_type.csv', index_col=0)

#File 4

by_sales_price_USA = pd.read_csv('houses_sold_by_sales_price_USA.csv', index_col = 0)

#File 5
status_2021 = pd.read_csv('construction_status_2021.csv', index_col = 0)

status_2021

#File 6 (For the future, I will explore micro trends in the construction industry to extrapolate strategies for 
#investors)

exterior_type = pd.read_csv('exterior_type.csv',index_col =1)

# %%
auth_not_started.reset_index(inplace=True)#index  will be used as column

# %%
fig = go.Figure()


fig.add_trace(go.Bar(x = auth_not_started.Date, y = auth_not_started['United States'], name = 'USA',marker_color='gray'))

fig.add_trace(go.Bar(x = auth_not_started.Date, y = auth_not_started['North East'],showlegend=False,marker_color='darkblue'))
fig.add_trace(go.Scatter(x = auth_not_started.Date, y = auth_not_started['North East'], name = 'Northeast-line', mode = 'lines'))
fig.add_trace(go.Bar(x = auth_not_started.Date, y = auth_not_started['West'], showlegend=False,))
fig.add_trace(go.Scatter(x = auth_not_started.Date, y = auth_not_started['West'],name = 'West-line',mode='lines',))

fig.add_trace(go.Bar(x = auth_not_started.Date, y = auth_not_started['South'], showlegend=False,marker_color = 'darkblue'))
fig.add_trace(go.Scatter(x = auth_not_started.Date, y = auth_not_started['South'], name = 'South-line',mode = 'lines'))
fig.add_trace(go.Bar(x = auth_not_started.Date, y = auth_not_started['Mid West'], showlegend=False,marker_color = 'darkblue'))
fig.add_trace(go.Scatter(x = auth_not_started.Date, y = auth_not_started['Mid West'], name = 'Midwest-line',mode = 'lines'))

fig.update_layout(title_text = '<b>Permits Authorized but Not Started<b>',
                  title_x = 0.5,
                  
                  yaxis_title = 'Not Started in Thousands',
                  yaxis_range = [0,200],
                  yaxis_dtick = 10,
                  xaxis_title = 'Period By Quarter',
                  font = dict(family = 'verdana',
                             size = 12,
                             color = 'black',
                             ),
                  yaxis_showgrid = False,
                  yaxis_linecolor = 'white',
                  legend = dict(bgcolor ='white',
                                title = 'Legend',
                                font = dict(color = 'black',size = 8)
                               ),
                   paper_bgcolor = 'rgb(240, 240, 240)',
  plot_bgcolor = 'rgb(240, 240, 240)',
                  clickmode = 'select',
                  dragmode = 'drawline',
                  transition = dict(duration = 1000,
                                   easing = 'bounce-in',
                                   ordering = 'traces first'))
                  
                  
fig.add_vrect(x0 = '2020-12-1', x1 = '2021-12-30', col =1, fillcolor="gray",opacity=0.15, line_width=0)

fig.show()
# Out:
# <div>                            <div id="bc93a5cd-e6cb-462c-9df2-c84c961d2234" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bc93a5cd-e6cb-462c-9df2-c84c961d2234")) {                    Plotly.newPlot(                        "bc93a5cd-e6cb-462c-9df2-c84c961d2234",                        [{"marker":{"color":"gray"},"name":"USA","x":["2014-01-01","2014-02-01","2014-03-01","2014-04-01","2014-05-01","2014-06-01","2014-07-01","2014-08-01","2014-09-01","2014-10-01","2014-11-01","2014-12-01","2015-01-01","2015-02-01","2015-03-01","2015-04-01","2015-05-01","2015-06-01","2015-07-01","2015-08-01","2015-09-01","2015-10-01","2015-11-01","2015-12-01","2016-01-01","2016-02-01","2016-03-01","2016-04-01","2016-05-01","2016-06-01","2016-07-01","2016-08-01","2016-
# ...

# %%
                 
fig.write_image("/Users/tiko/Desktop/fig1.png")

# %%
# USA_corr = auth_not_started[['Date','United States']]
# USA_corr['Date'] = pd.to_datetime(USA_corr['Date'])
# USA_corr.set_index('Date',inplace = True)
# South_corr = auth_not_started[['Date','South']]
# South_corr['Date'] = pd.to_datetime(South_corr['Date'])
# South_corr.set_index('Date',inplace = True)


West_corr = auth_not_started[['Date','West']]
West_corr['Date'] = pd.to_datetime(West_corr['Date'])

West_corr.set_index('Date',inplace = True)

# %%
USacf = plot_acf(USA_corr,lags = 31)

# %%
Westacf = plot_acf(West_corr, lags = 31)

# %%
Southacf = plot_acf(South_corr, lags = 31)

# %%
ss = new_price_by_region.set_index('Region')

# %%
#sold_finance_type.reset_index(inplace = True)
'''Run The Above before displaying the figure'''
#sold_finance_type.drop(['index', 'level_0'], inplace = True, axis = 1)




fig2 = go.Figure()
fig2.add_trace(go.Scatter(x = sold_finance_type.Period, y = sold_finance_type['Conventional'], name = 'Conventional',stackgroup='one'))
fig2.add_trace(go.Scatter(x = sold_finance_type.Period, y = sold_finance_type['FHA Insured'], name = 'FHA Insured',stackgroup='two'))
fig2.add_trace(go.Scatter(x = sold_finance_type.Period, y = sold_finance_type['VA Guaranteed'], name = 'VA Guaranteed',stackgroup='three'))
fig2.add_trace(go.Scatter(x = sold_finance_type.Period, y = sold_finance_type['Cash'], name = 'Cash',stackgroup='four'))
fig2.update_layout(title_text = '<b>Type of Financing (2014 - 2021)<b>',
                  title_x = 0.5,
                  
                  yaxis_title = 'Count in Thousands',
                  yaxis_range = [0,250],
                  yaxis_dtick = 15,
                  xaxis_title = 'Period By Quarter',
                  font = dict(family = 'verdana',
                             size = 12,
                             color = 'black',
                             ),
                  yaxis_showgrid = False,
                  yaxis_linecolor = 'white',
                  legend = dict(bgcolor ='white',
                                title = 'Legend',
                                font = dict(color = 'black',size = 8)
                               ),
                   paper_bgcolor = 'rgb(240, 240, 240)',
                  plot_bgcolor = 'rgb(240, 240, 240)',
                  clickmode = 'select',
                  dragmode = 'drawline',
                  transition = dict(duration = 1000,
                                   easing = 'bounce-in',
                                   ordering = 'traces first'))

fig2.add_vrect(x0 = '2021Q1', x1 = '2021Q4', col =1, fillcolor="gray",opacity=0.25, line_width=0,annotation_text="decline")
# Out:
# <div>                            <div id="abecbc6a-afd3-4751-91fc-ab1e261e76f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("abecbc6a-afd3-4751-91fc-ab1e261e76f2")) {                    Plotly.newPlot(                        "abecbc6a-afd3-4751-91fc-ab1e261e76f2",                        [{"name":"Conventional","stackgroup":"one","x":["2014Q1","2014Q2","2014Q3","2014Q4","2015Q1","2015Q2","2015Q3","2015Q4","2016Q1","2016Q2","2016Q3","2016Q4","2017Q1","2017Q2","2017Q3","2017Q4","2018Q1","2018Q2","2018Q3","2018Q4","2019Q1","2019Q2","2019Q3","2019Q4","2020Q1","2020Q2","2020Q3","2020Q4","2021Q1","2021Q2","2021Q3","2021Q4"],"y":[76,83,78,76,91,95,83,79,93,108,106,89,113,121,104,104,124,134,108,94,120,125,117,107,125,131,172,139,163,148,131,123],"type":"
# ...

# %%
sold_finance_type
# Out:
#     Period  Total Sold  Total Sold Rate of Change  Conventional  \
# 0   2014Q1         106                        NaN            76
# 1   2014Q2         120                   0.132075            83
# 2   2014Q3         107                  -0.108333            78
# 3   2014Q4         104                  -0.028037            76
# 4   2015Q1         131                   0.259615            91
# 5   2015Q2         140                   0.068702            95
# 6   2015Q3         119                  -0.150000            83
# 7   2015Q4         112                  -0.058824            79
# 8   2016Q1         134                   0.196429            93
# 9   2016Q2         158                   0.179104           108
# 10  2016Q3         144                  -0.088608           106
# 11  2016Q4         125                  -0.131944            89
# 12  2017Q1         156                   0.248000           113
# 13  2017Q2         170                   0.089744           121
# ...

# %%
fig3 = make_subplots(rows=2, cols=2)
closer_look_finance= sold_finance_type.loc[20:31]
fig3.add_trace(go.Scatter(x = closer_look_finance.Period, y = closer_look_finance['Conventional'],name = 'Conventional'),row=1, col=1)
fig3.add_trace(go.Scatter(x = closer_look_finance.Period, y = closer_look_finance['FHA Insured'], name = 'FHA Insured Rate of Change'),row=1, col=2)
fig3.add_trace(go.Scatter(x = closer_look_finance.Period, y = closer_look_finance['VA Guaranteed'], name = 'VA Guaranteed'),row=2, col=1)
fig3.add_trace(go.Scatter(x = closer_look_finance.Period, y = closer_look_finance['Cash'], name = 'Cash'),row=2, col=2)



fig3.add_vrect(x0 = '2021Q1', x1 = '2021Q4', col =1, row=1, fillcolor="gray",opacity=0.25, line_width=0,annotation_text="steep decline",exclude_empty_subplots=False,)
fig3.add_vrect(x0 = '2021Q2', x1 = '2021Q4', col =1, row=2, fillcolor="gray",opacity=0.25, line_width=0,annotation_text="steep decline",exclude_empty_subplots=False)

fig3.add_vrect(x0 = '2021Q2', x1 = '2021Q4', col =2, row=2, fillcolor="gray",opacity=0.25, line_width=0,annotation_text="steep decline",exclude_empty_subplots=False)
fig3.add_vrect(x0 = '2021Q1', x1 = '2021Q4', col =2, row=1, fillcolor="gray",opacity=0.25, line_width=0,annotation_text="steep decline",exclude_empty_subplots=False)

fig3.update_layout( paper_bgcolor = 'rgb(240, 240, 240)',
                  plot_bgcolor = 'rgb(240, 240, 240)',
                title_text = '<b>Type of Financing (2020 - 2021)<b>',
                  title_x = 0.5,
                   
                  
                  yaxis_title = 'Count in Thousands',
                  
                  
                  font = dict(family = 'verdana',
                             size = 12,
                             color = 'black',
                             ),
                  yaxis_showgrid = False,
                  yaxis_linecolor = 'white',
                  legend = dict(bgcolor ='white',
                                title = 'Legend',
                                font = dict(color = 'black',size = 8)
                               ),
                 
                  clickmode = 'select',
                  dragmode = 'drawline',
                  transition = dict(duration = 1000,
                                   easing = 'bounce-in',
                                   ordering = 'traces first'))

fig3.update_xaxes(showticklabels=False) # hide all the xticks
fig3.update_xaxes(showticklabels=True, row=2, col=1)
fig3.update_xaxes(showticklabels=True, row=2, col=2)
# Out:
# <div>                            <div id="da4d2e27-84d6-450c-bfa1-63f4eb924929" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da4d2e27-84d6-450c-bfa1-63f4eb924929")) {                    Plotly.newPlot(                        "da4d2e27-84d6-450c-bfa1-63f4eb924929",                        [{"name":"Conventional","x":["2019Q1","2019Q2","2019Q3","2019Q4","2020Q1","2020Q2","2020Q3","2020Q4","2021Q1","2021Q2","2021Q3","2021Q4"],"y":[120,125,117,107,125,131,172,139,163,148,131,123],"type":"scatter","xaxis":"x","yaxis":"y"},{"name":"FHA Insured Rate of Change","x":["2019Q1","2019Q2","2019Q3","2019Q4","2020Q1","2020Q2","2020Q3","2020Q4","2021Q1","2021Q2","2021Q3","2021Q4"],"y":[30,35,26,29,32,40,45,37,43,26,23,14],"type":"scatter","xaxis":"x2","yaxis":"y2
# ...

# %%
#by_sales_price_USA.reset_index(inplace = True)

#by_sales_price_USA.drop(['index', 'level_0'],axis = 1, inplace = True)
#by_sales_price_USA


fig4 = go.Figure()
fig4.add_trace(go.Scatter(x = by_sales_price_USA.Period, y = by_sales_price_USA['150-199'], name = '150-199'))
fig4.add_trace(go.Scatter(x = by_sales_price_USA.Period, y = by_sales_price_USA['200-249'], name = '200-249'))
fig4.add_trace(go.Scatter(x = by_sales_price_USA.Period, y = by_sales_price_USA['250-299'],  name = '250-299'))
fig4.add_trace(go.Scatter(x = by_sales_price_USA.Period, y = by_sales_price_USA['300-399'], name = '300-399'))
fig4.add_trace(go.Scatter(x = by_sales_price_USA.Period, y = by_sales_price_USA['400-499'],  name = '400-499'))
fig4.add_trace(go.Scatter(x = by_sales_price_USA.Period, y = by_sales_price_USA['500-749'], name = '500-749'))
fig4.add_trace(go.Scatter(x = by_sales_price_USA.Period, y = by_sales_price_USA['750 and Above'],  name = '750 and Above'))



fig4.update_layout( paper_bgcolor = 'rgb(240, 240, 240)',
                  plot_bgcolor = 'rgb(240, 240, 240)',
                title_text = '<b>Sales By Price Range - USA<b>',
                  title_x = 0.5,
                   
                  
                  yaxis_title = 'Count in Thousands',
                  
                  
                   
                  font = dict(family = 'verdana',
                             size = 12,
                             color = 'black',
                             ),
                  yaxis_showgrid = False,
                  yaxis_linecolor = 'white',
                  legend = dict(bgcolor ='white',
                                title = 'Legend',
                                font = dict(color = 'black',size = 8)
                               ),
                 
                  clickmode = 'select',
                  dragmode = 'drawline',
                  transition = dict(duration = 1000,
                                   easing = 'bounce-in',
                                   ordering = 'traces first'))
# Out:
# <div>                            <div id="6b231401-e8fd-418f-8596-85e2e141a215" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6b231401-e8fd-418f-8596-85e2e141a215")) {                    Plotly.newPlot(                        "6b231401-e8fd-418f-8596-85e2e141a215",                        [{"name":"150-199","x":["2014Q1 ","2014Q2 ","2014Q3 ","2014Q4 ","2015Q1 ","2015Q2 ","2015Q3 ","2015Q4 ","2016Q1 ","2016Q2 ","2016Q3 ","2016Q4 ","2017Q1 ","2017Q2 ","2017Q3 ","2017Q4 ","2018Q1 ","2018Q2 ","2018Q3 ","2018Q4 ","2019Q1 ","2019Q2 ","2019Q3 ","2019Q4 ","2020Q1 ","2020Q2 ","2020Q3 ","2020Q4 ","2021Q1 ","2021Q2 ","2021Q3 ","2021Q4 "],"y":[18,20,18,15,20,22,18,13,18,23,19,16,17,16,16,12,15,20,11,10,13,14,14,11,14,16,13,9,7,2,1,1],"type":"scatter"},{"name":
# ...

# %%
fig4.write_image("/Users/tiko/Desktop/fig4.png")

# %%
sales_price_USA_change = by_sales_price_USA.loc[20:]['Period'].agg(['mean'])
#fig5 = go.Figure()

#fig5.add_trace(go.Bar(x = sales_price_USA_change ))
#sales_price_USA_change
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/r1/cq24m6mn5j1c896ftltp3tjw0000gn/T/ipykernel_32651/2612954282.py in <module>
# ----> 1 sales_price_USA_change = by_sales_price_USA.loc[20:]['Period'].agg(['mean'])
#       2 #fig5 = go.Figure()
#       3
#       4 #fig5.add_trace(go.Bar(x = sales_price_USA_change ))
#       5 #sales_price_USA_change
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in aggregate(self, func, axis, *args, **kwargs)
#    4225
#    4226         op = SeriesApply(self, func, convert_dtype=False, args=args, kwargs=kwargs)
# -> 4227         result = op.agg()
#    4228         return result
#    4229
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in agg(self)
#    1044
#    1045     def agg(self):
# -> 1046         result = super().agg()
#    1047         if result is None:
# ...

# %%
sales_price_USA_change
# Out:
#              USA  USA Rate of Change     0-125  0-125 Rate of Change  125-149  \
# mean  188.833333            0.031997  0.666667                   inf      1.5
#
#       125-149 Rate of Change   150-199  150-199 Rate of Change    200-249  \
# mean                     inf  9.583333                -0.11279  24.583333
#
#       200-249 Rate of Change    250-299  250-299 Rate of Change  300-399  \
# mean               -0.041153  30.083333                 0.01661    51.25
#
#       300-399 Rate of Change    400-499  400-499 Rate of Change    500-749  \
# mean                0.049583  31.666667                0.070258  28.333333
#
#       500-749 Rate of Change  750 and Above  750 and Above Rate of Change
# mean                0.085179      11.166667                      0.115891

# %%
by_sales_price_USA.loc[20:]
# Out:
#      Period  USA  USA Rate of Change  0-125  0-125 Rate of Change  125-149  \
# 20  2019Q1   174            0.380952      1                  -0.5        4
# 21  2019Q2   186            0.068966      1                   0.0        3
# 22  2019Q3   168           -0.096774      1                   0.0        2
# 23  2019Q4   154           -0.083333      1                   0.0        2
# 24  2020Q1   181            0.175325      1                   0.0        2
# 25  2020Q2   196            0.082873      1                   0.0        2
# 26  2020Q3   243            0.239796      0                  -1.0        1
# 27  2020Q4   202           -0.168724      0                   NaN        0
# 28  2021Q1   229            0.133663      1                   inf        1
# 29  2021Q2   200           -0.126638      0                  -1.0        1
# 30  2021Q3   175           -0.125000      0                   NaN        0
# ...

# %%
under_construction = status_2021[status_2021.Status == 'Under Construction']
completed = status_2021[status_2021.Status == 'Construction Completed']
started = status_2021[status_2021.Status == 'Construction Started']

# %%
#started = started.reset_index()
#started.drop(['index', 'level_0'], inplace = True, axis = 1)
#completed =completed.reset_index()
#completed.drop(['index', 'level_0'], inplace = True, axis = 1)
#under_construction =under_construction.reset_index()
#under_construction.drop('index', inplace = True, axis = 1)
# Out:
#        Period    USA  NorthEast  Midwest  South   West              Status  \
# 0     January  597.3       56.6     83.5  296.6  160.6  Under Construction
# 1    February  600.4       55.4     78.6  300.8  165.6  Under Construction
# 2       March  619.0       56.1     84.1  307.9  170.9  Under Construction
# 3       April  636.9       58.8     87.4  316.2  174.5  Under Construction
# 4         May  657.9       59.8     95.1  322.7  180.4  Under Construction
# 5        June  687.6       61.9     96.8  343.9  185.1  Under Construction
# 6        July  714.2       61.2    101.9  361.6  189.5  Under Construction
# 7      August  729.3       62.7    104.2  374.7  187.7  Under Construction
# 8   September  741.9       63.8    105.8  380.7  191.6  Under Construction
# 9    Octoberr  750.0       63.5    106.8  387.3  192.4  Under Construction
# 10  Novemberr  760.7       64.0    104.9  397.7  194.1  Under Construction
# ...

# %%
fig6 = make_subplots(rows=1, cols=3, subplot_titles=("<i>Started<i>", "<i>Completed<i>", "<i>Under Construction<i>"))
fig6.add_trace(go.Scatter(x = started.Period, y = started.USA, name = 'USA', legendgroup='1'),row=1, col=1,)
fig6.add_trace(go.Scatter(x = started.Period, y = started.NorthEast, name  = 'NorthEast', legendgroup='2' ),row=1, col=1)
fig6.add_trace(go.Scatter(x = started.Period, y = started.Midwest, name = 'MidWest', legendgroup='3' ),row=1, col=1)
fig6.add_trace(go.Scatter(x = started.Period, y = started.South , name = 'South', legendgroup='4'),row=1, col=1)
fig6.add_trace(go.Scatter(x = started.Period, y = started.West , name = 'West', legendgroup='5'),row=1, col=1)



fig6.add_trace(go.Scatter(x = completed.Period, y = completed.USA, name = 'USA' , showlegend=False,legendgroup='1',),row=1, col=2,)
fig6.add_trace(go.Scatter(x = completed.Period, y = completed.NorthEast, name  = 'NorthEast', showlegend=False,legendgroup='2' ),row=1, col=2)
fig6.add_trace(go.Scatter(x = completed.Period, y = completed.Midwest, name = 'MidWest', showlegend=False,legendgroup='3' ),row=1, col=2)
fig6.add_trace(go.Scatter(x = completed.Period, y = completed.South , name = 'South', showlegend=False,legendgroup='4'),row=1, col=2)
fig6.add_trace(go.Scatter(x = completed.Period, y = completed.West , name = 'West', showlegend=False,legendgroup='5'),row=1, col=2)


fig6.add_trace(go.Scatter(x = under_construction.Period, y = under_construction.USA, name = 'USA', showlegend=False,legendgroup='1' ),row=1, col=3,)
fig6.add_trace(go.Scatter(x = under_construction.Period, y = under_construction.NorthEast, name  = 'NorthEast', showlegend=False,legendgroup='2' ),row=1, col=3)
fig6.add_trace(go.Scatter(x = under_construction.Period, y = under_construction.Midwest, name = 'MidWest', showlegend=False,legendgroup='3' ),row=1, col=3)
fig6.add_trace(go.Scatter(x = under_construction.Period, y = under_construction.South , name = 'South', showlegend=False,legendgroup='4'),row=1, col=3)
fig6.add_trace(go.Scatter(x = under_construction.Period, y = under_construction.West , name = 'West', showlegend=False,legendgroup='5'),row=1, col=3)






fig6.update_layout(title = 'Construction Status for 2021 - By Region',
                  paper_bgcolor = 'rgb(240, 240, 240)',
                  plot_bgcolor = 'rgb(240, 240, 240)',
                title_text = '<b>Construction Status for 2021 - By Region<b>',
                   
                  title_x = 0.5,
                   
                  
                  yaxis_title = '<i>Count in Thousands<i>',
                  
                  
                  font = dict(family = 'verdana',
                             size = 14,
                             color = 'black',
                             ),
                  yaxis_showgrid = False,
                  yaxis_linecolor = 'white',
                  legend = dict(bgcolor ='white',
                                title = 'Legend',
                                font = dict(color = 'black',size = 8)
                               ),
                 
                  clickmode = 'select',
                  dragmode = 'drawline',
                  transition = dict(duration = 1000,
                                   easing = 'bounce-in',
                                   ordering = 'traces first'))
# Out:
# <div>                            <div id="81c4b6e4-5011-48b3-9c4c-399a85298cd8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("81c4b6e4-5011-48b3-9c4c-399a85298cd8")) {                    Plotly.newPlot(                        "81c4b6e4-5011-48b3-9c4c-399a85298cd8",                        [{"legendgroup":"1","name":"USA","x":["January","February","March","April","May","June","July","August","September","Octoberr","Novemberr","Decemberp"],"y":[77.9,74.6,102.8,97.2,100.5,111.6,104.6,98.0,93.5,91.6,89.5,81.0],"type":"scatter","xaxis":"x","yaxis":"y"},{"legendgroup":"2","name":"NorthEast","x":["January","February","March","April","May","June","July","August","September","Octoberr","Novemberr","Decemberp"],"y":[5.0,3.4,7.2,6.7,5.6,8.5,4.3,6.1,6.4,4.8,4.
# ...

# %%
exterior_type
# Out:
#    Period  Total  Brick  Wood  Stucco  Vinyl Sliding  Fiber Cement
# 0    2014    620    141    32     140            184           112
# 1    2015    648    148    34     157            174           122
# 2    2016    738    162    33     178            200           147
# 3    2017    795    172    39     194            213           161
# 4    2018    840    178    45     212            215           171
# 5    2019    903    179    44     245            228           190
# 6    2020    912    176    43     248            227           201

# %%
NE = new_price_by_region[new_price_by_region.Region == 'North East'].dropna(axis = 1,how = 'all')
S = new_price_by_region[new_price_by_region.Region == 'South'].dropna(axis = 1,how = 'all')
W = new_price_by_region[new_price_by_region.Region == 'West'].dropna(axis = 1,how = 'all')
MW = new_price_by_region[new_price_by_region.Region == 'Mid West'].dropna(axis = 1,how = 'all')

# %%
W
# Out:
#      Period  Total Under 200  200-299  300-499  500-749  750 and Over Region
# 32  2014Q1     100         7       33       42     10.0           8.0   West
# 33  2014Q2     100         8       31       42     14.0           5.0   West
# 34  2014Q3     100        10       32       40     12.0           6.0   West
# 35  2014Q4     100         9       27       43     12.0           8.0   West
# 36  2015Q1     100         6       31       42     14.0           7.0   West
# 37  2015Q2     100         8       30       46     13.0           4.0   West
# 38  2015Q3     100         7       32       40     12.0           8.0   West
# 39  2015Q4     100         7       28       41     17.0           7.0   West
# 40  2016Q1     100         4       32       43     15.0           6.0   West
# 41  2016Q2     100         3       24       50     16.0           7.0   West
# 42  2016Q3     100         5       27       45     15.0           8.0   West
# ...

# %%
NE
# Out:
#      Period  Total Under 200  200-299  300-499  500-749  750 and Over  \
# 0   2014Q1     100        12       30       30     17.0          10.0
# 1   2014Q2     100        10       29       28     19.0          14.0
# 2   2014Q3     100         5       19       31     23.0          21.0
# 3   2014Q4     100       (Z)       29       32     22.0          17.0
# 4   2015Q1     100         7       17       34     20.0          22.0
# 5   2015Q2     100         6       17       46     20.0          12.0
# 6   2015Q3     100        10       22       38     18.0          12.0
# 7   2015Q4     100         7       17       26     20.0          30.0
# 8   2016Q1     100         5       15       46     24.0          10.0
# 9   2016Q2     100         4       25       27     28.0          17.0
# 10  2016Q3     100         7       19       36     17.0          22.0
# 11  2016Q4     100         4       21       46     15.0          14.0
# ...

# %%
S
# Out:
#      Period  Total  200-299  300-499 Region  Under 150  150-199  500 and Over
# 64  2014Q1     100       32       28  South        9.0     22.0           9.0
# 65  2014Q2     100       31       30  South        8.0     20.0          12.0
# 66  2014Q3     100       32       27  South       11.0     22.0           9.0
# 67  2014Q4     100       33       29  South        7.0     18.0          13.0
# 68  2015Q1     100       38       27  South        6.0     19.0          10.0
# 69  2015Q2     100       35       27  South        5.0     21.0          11.0
# 70  2015Q3     100       31       33  South        7.0     19.0          10.0
# 71  2015Q4     100       36       32  South        7.0     14.0          11.0
# 72  2016Q1     100       33       32  South        7.0     17.0          11.0
# 73  2016Q2     100       32       33  South        5.0     20.0          11.0
# 74  2016Q3     100       33       34  South        5.0     17.0          10.0
# ...

# %%
MW
# Out:
#       Period  Total  200-299  300-499    Region  Under 150  150-199  \
# 96   2014Q1     100       34       31  Mid West       12.0     17.0
# 97   2014Q2     100       34       28  Mid West        8.0     21.0
# 98   2014Q3     100       36       30  Mid West        7.0     16.0
# 99   2014Q4     100       28       32  Mid West       11.0     18.0
# 100  2015Q1     100       34       31  Mid West        4.0     20.0
# 101  2015Q2     100       39       29  Mid West        5.0     17.0
# 102  2015Q3     100       34       37  Mid West        4.0     20.0
# 103  2015Q4     100       37       34  Mid West        3.0     18.0
# 104  2016Q1     100       38       34  Mid West        4.0     18.0
# 105  2016Q2     100       37       34  Mid West        4.0     19.0
# 106  2016Q3     100       36       36  Mid West        4.0     16.0
# 107  2016Q4     100       36       35  Mid West        1.0     14.0
# 108  2017Q1     100       37       35  Mid West        2.0     16.0
# ...

# %%
fig8 = make_subplots(rows=1, cols=2, subplot_titles=("<i>South<i>","<i>MidWest"
                                                    ))


fig8.add_trace(go.Scatter(x = S.Period, y =S['Under 150'], name='Under 150',  legendgroup='1' ),row=1,col=1)
fig8.add_trace(go.Scatter(x = S.Period, y =S['150-199'],name='150-199',  legendgroup='2' ),row=1,col=1)
fig8.add_trace(go.Scatter(x = S.Period, y =S['200-299'],name='200-299',  legendgroup='3' ),row=1,col=1)
fig8.add_trace(go.Scatter(x = S.Period, y =S['300-499'],name='300-499',  legendgroup='4'),row=1,col=1)
fig8.add_trace(go.Scatter(x = S.Period, y =S['500 and Over'],name='500 and Over',  legendgroup='5' ),row=1,col=1)

fig8.add_trace(go.Scatter(x = S.Period, y =MW['Under 150'], name='Under 150',legendgroup='1', showlegend=False ),row=1,col=2)
fig8.add_trace(go.Scatter(x = S.Period, y =MW['150-199'],name='150-199',legendgroup='2', showlegend=False ),row=1,col=2)
fig8.add_trace(go.Scatter(x = S.Period, y =MW['200-299'],name='200-299', legendgroup='3',showlegend=False ),row=1,col=2)
fig8.add_trace(go.Scatter(x = S.Period, y =MW['300-499'],name='300-499',legendgroup='4', showlegend=False),row=1,col=2)
fig8.add_trace(go.Scatter(x = S.Period, y =MW['500 and Over'],name='500 and Over', legendgroup='5',showlegend=False ),row=1,col=2)


fig8.update_layout(title = 'Home Prices for US regions: South & Mid West',
                  paper_bgcolor = 'rgb(240, 240, 240)',
                  plot_bgcolor = 'rgb(240, 240, 240)',
                title_text = '<b>Home Prices for US regions: South & Mid West<b>',
                   
                  title_x = 0.5,
                   
                  
                  yaxis_title = '<i>Count in Thousands<i>',
                  
                  
                  font = dict(family = 'verdana',
                             size = 14,
                             color = 'black',
                             ),
                  yaxis_showgrid = False,
                  yaxis_linecolor = 'white',
                  legend = dict(bgcolor ='white',
                                title = 'Legend',
                                font = dict(color = 'black',size = 8)
                               ),
                 
                  clickmode = 'select',
                  dragmode = 'drawline',
                  transition = dict(duration = 1000,
                                   easing = 'bounce-in',
                                   ordering = 'traces first'))
# Out:
# <div>                            <div id="ab00ba0d-5397-47d5-8ca4-47fc5f72fde9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ab00ba0d-5397-47d5-8ca4-47fc5f72fde9")) {                    Plotly.newPlot(                        "ab00ba0d-5397-47d5-8ca4-47fc5f72fde9",                        [{"legendgroup":"1","name":"Under 150","x":["2014Q1 ","2014Q2 ","2014Q3 ","2014Q4 ","2015Q1 ","2015Q2 ","2015Q3 ","2015Q4 ","2016Q1 ","2016Q2 ","2016Q3 ","2016Q4 ","2017Q1 ","2017Q2 ","2017Q3 ","2017Q4 ","2018Q1 ","2018Q2 ","2018Q3 ","2018Q4 ","2019Q1 ","2019Q2 ","2019Q3 ","2019Q4 ","2020Q1 ","2020Q2 ","2020Q3 ","2020Q4 ","2021Q1 ","2021Q2 ","2021Q3 ","2021Q4 "],"y":[9.0,8.0,11.0,7.0,6.0,5.0,7.0,7.0,7.0,5.0,5.0,4.0,6.0,4.0,5.0,4.0,5.0,5.0,4.0,5.0,4.0,2.0,2.0,2.0,3
# ...

# %%
NE
# Out:
#      Period  Total Under 200  200-299  300-499  500-749  750 and Over  \
# 0   2014Q1     100        12       30       30     17.0          10.0
# 1   2014Q2     100        10       29       28     19.0          14.0
# 2   2014Q3     100         5       19       31     23.0          21.0
# 3   2014Q4     100       (Z)       29       32     22.0          17.0
# 4   2015Q1     100         7       17       34     20.0          22.0
# 5   2015Q2     100         6       17       46     20.0          12.0
# 6   2015Q3     100        10       22       38     18.0          12.0
# 7   2015Q4     100         7       17       26     20.0          30.0
# 8   2016Q1     100         5       15       46     24.0          10.0
# 9   2016Q2     100         4       25       27     28.0          17.0
# 10  2016Q3     100         7       19       36     17.0          22.0
# 11  2016Q4     100         4       21       46     15.0          14.0
# ...

# %%
fig9 = make_subplots(rows=1, cols=2, subplot_titles=("<i>North East<i>","<i>West"
                                                    ))


fig9.add_trace(go.Scatter(x = S.Period, y =NE['Under 200'], name='Under 200',  legendgroup='1' ),row=1,col=1)
fig9.add_trace(go.Scatter(x = S.Period, y =NE['200-299'],name='200-299',  legendgroup='2' ),row=1,col=1)
fig9.add_trace(go.Scatter(x = S.Period, y =NE['300-499'],name='300-499',  legendgroup='3' ),row=1,col=1)
fig9.add_trace(go.Scatter(x = S.Period, y =NE['500-749'],name='500-749',  legendgroup='4'),row=1,col=1)
fig9.add_trace(go.Scatter(x = S.Period, y =NE['750 and Over'],name='750 and Over',  legendgroup='5' ),row=1,col=1)

fig9.add_trace(go.Scatter(x = S.Period, y =W['Under 200'], name='Under 200',legendgroup='1', showlegend=False ),row=1,col=2)
fig9.add_trace(go.Scatter(x = S.Period, y =W['200-299'],name='200-299',legendgroup='2', showlegend=False ),row=1,col=2)
fig9.add_trace(go.Scatter(x = S.Period, y =W['300-499'],name='300-499', legendgroup='3',showlegend=False ),row=1,col=2)
fig9.add_trace(go.Scatter(x = S.Period, y =W['500-749'],name='500-749',legendgroup='4', showlegend=False),row=1,col=2)
fig9.add_trace(go.Scatter(x = S.Period, y =W['750 and Over'],name='750 and Over', legendgroup='5',showlegend=False ),row=1,col=2)



fig9.update_layout(title = 'Home Prices for US regions: NorthEast & West',
                  paper_bgcolor = 'rgb(240, 240, 240)',
                  plot_bgcolor = 'rgb(240, 240, 240)',
                title_text = '<b>Home Prices for US regions: NorthEast & West<b>',
                   
                  title_x = 0.5,
                   
                  
                  yaxis_title = '<i>Count in Thousands<i>',
                  
                  
                  font = dict(family = 'verdana',
                             size = 14,
                             color = 'black',
                             ),
                  yaxis_showgrid = False,
                  yaxis_linecolor = 'white',
                  legend = dict(bgcolor ='white',
                                title = 'Legend',
                                font = dict(color = 'black',size = 8)
                               ),
                 
                  clickmode = 'select',
                  dragmode = 'drawline',
                  transition = dict(duration = 1000,
                                   easing = 'bounce-in',
                                   ordering = 'traces first'))
# Out:
# <div>                            <div id="60aabeb4-38b6-4320-b5f0-4f428ee63a15" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("60aabeb4-38b6-4320-b5f0-4f428ee63a15")) {                    Plotly.newPlot(                        "60aabeb4-38b6-4320-b5f0-4f428ee63a15",                        [{"legendgroup":"1","name":"Under 200","x":["2014Q1 ","2014Q2 ","2014Q3 ","2014Q4 ","2015Q1 ","2015Q2 ","2015Q3 ","2015Q4 ","2016Q1 ","2016Q2 ","2016Q3 ","2016Q4 ","2017Q1 ","2017Q2 ","2017Q3 ","2017Q4 ","2018Q1 ","2018Q2 ","2018Q3 ","2018Q4 ","2019Q1 ","2019Q2 ","2019Q3 ","2019Q4 ","2020Q1 ","2020Q2 ","2020Q3 ","2020Q4 ","2021Q1 ","2021Q2 ","2021Q3 ","2021Q4 "],"y":["12","10","5","(Z)","7","6","10","7","5","4","7","4","2","1","2","0","6","3","1","1","7","4","2","
# ...

# %%
# exterior_type.reset_index(inplace = True)
# exterior_type.drop('index', inplace = True,axis = 1)
# exterior_type.drop('Unnamed: 0', inplace = True,axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/r1/cq24m6mn5j1c896ftltp3tjw0000gn/T/ipykernel_33500/4089988842.py in <module>
#       1 exterior_type.reset_index(inplace = True)
# ----> 2 exterior_type.drop('index', inplace = True,axis = 1)
#       3 exterior_type.drop('Unnamed: 0', inplace = True,axis = 1)
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
# ...

# %%
fig7 = go.Figure()
fig7.add_trace(go.Bar(x = exterior_type.Period, y = exterior_type.Brick, name = 'Brick', marker_color = 'brown'))
fig7.add_trace(go.Bar(x = exterior_type.Period, y = exterior_type.Wood, name = 'Wood', marker_color = 'blue'))
fig7.add_trace(go.Bar(x = exterior_type.Period, y = exterior_type.Stucco, name = 'Stucco', marker_color = 'darkblue'))
fig7.add_trace(go.Bar(x = exterior_type.Period, y = exterior_type['Vinyl Sliding'], name = 'Vinyl', marker_color = 'tan'))
fig7.add_trace(go.Bar(x = exterior_type.Period, y = exterior_type['Fiber Cement'], name = 'Fiber Cement', marker_color = 'green'))


fig7.add_trace(go.Scatter(x = exterior_type.Period, y = exterior_type['Fiber Cement'], name = 'Fiber Cement line',mode = 'lines',marker_color = 'black'))


fig7.update_layout(title = 'Micro-Trends to Analyze',
                  paper_bgcolor = 'rgb(240, 240, 240)',
                  plot_bgcolor = 'rgb(240, 240, 240)',
                title_text = '<b>Micro-Trends to Analyze<b>',
                   
                  title_x = 0.5,
                   
                  
                  yaxis_title = '<i>Count in Thousands<i>',
                  
                  
                  font = dict(family = 'verdana',
                             size = 14,
                             color = 'black',
                             ),
                  yaxis_showgrid = False,
                  yaxis_linecolor = 'white',
                  legend = dict(bgcolor ='white',
                                title = 'Legend',
                                font = dict(color = 'black',size = 8)
                               ),
                 
                  clickmode = 'select',
                  dragmode = 'drawline',
                  transition = dict(duration = 1000,
                                   easing = 'bounce-in',
                                   ordering = 'traces first'))
# Out:
# <div>                            <div id="f06f811d-e746-42da-b9ea-f001091f5392" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f06f811d-e746-42da-b9ea-f001091f5392")) {                    Plotly.newPlot(                        "f06f811d-e746-42da-b9ea-f001091f5392",                        [{"marker":{"color":"brown"},"name":"Brick","x":[2014,2015,2016,2017,2018,2019,2020],"y":[141,148,162,172,178,179,176],"type":"bar"},{"marker":{"color":"blue"},"name":"Wood","x":[2014,2015,2016,2017,2018,2019,2020],"y":[32,34,33,39,45,44,43],"type":"bar"},{"marker":{"color":"darkblue"},"name":"Stucco","x":[2014,2015,2016,2017,2018,2019,2020],"y":[140,157,178,194,212,245,248],"type":"bar"},{"marker":{"color":"tan"},"name":"Vinyl","x":[2014,2015,2016,2017,2018,2019,
# ...

# %%
fig3.write_image("/Users/tiko/Desktop/fig3.png")
