# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import chart_studio.plotly as py
import seaborn as sns
import plotly.express as px
import cufflinks as cf
# %matplotlib inline
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
#init_notebook_mode(connected = True)
cf.go_offline()
import plotly.graph_objects as go
from pandas.plotting import autocorrelation_plot
import datetime
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
from plotly.subplots import make_subplots

# %%
'''Setting option for pandas to show maximum rows and columns'''

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
'''
File 1 --> 'new_price_by_region' --> new houses sold in 4 regions based on price range of homes.
File 2 --> 'auth_not_started.csv' --> authorized permits but not yet started homes. 
File 3 --> 'sold_finance_type.csv' -- > the type if financing for a loan and the rate of change.
File 4 --> houses_sold_by_sales_price_USA.csv' -->New Houses sold in the USA based on price range.
File 5 --> 'construction_status_2021.csv' --> Construction status in the usa and regions in 2021. The status categories 
are [started, completed, under construction]. 

'''
import pandas as pd


#File 1
auth_not_started = pd.read_csv('auth_not_started.csv',index_col=0)

#File 2
new_price_by_region = pd.read_csv('new_price_by_region', index_col=0)

#File 3
sold_finance_type =  pd.read_csv('sold_finance_type.csv', index_col=0)

#File 4

by_sales_price_USA = pd.read_csv('houses_sold_by_sales_price_USA.csv', index_col = 0)

#File 5
status_2021 = pd.read_csv('construction_status_2021.csv', index_col = 0)

status_2021

#File 6 (For the future, I will explore micro trends in the construction industry to extrapolate strategies for 
#investors)

exterior_type = pd.read_csv('exterior_type.csv',index_col =1)

# %%
auth_not_started.reset_index(inplace=True)

# %%
fig = go.Figure()


fig.add_trace(go.Bar(x = auth_not_started.Date, y = auth_not_started['United States'], name = 'USA',marker_color='gray'))

fig.add_trace(go.Bar(x = auth_not_started.Date, y = auth_not_started['North East'], name = 'Northeast',marker_color='red'))
fig.add_trace(go.Scatter(x = auth_not_started.Date, y = auth_not_started['North East'], name = 'Northeast-line', mode = 'lines'))
fig.add_trace(go.Bar(x = auth_not_started.Date, y = auth_not_started['West'], name = 'West',))
fig.add_trace(go.Scatter(x = auth_not_started.Date, y = auth_not_started['West'],name = 'West-line',mode='lines',))

fig.add_trace(go.Bar(x = auth_not_started.Date, y = auth_not_started['South'], name = 'South',marker_color = '#054907'))
fig.add_trace(go.Scatter(x = auth_not_started.Date, y = auth_not_started['South'], name = 'South-line',mode = 'lines'))
fig.add_trace(go.Bar(x = auth_not_started.Date, y = auth_not_started['Mid West'], name = 'Midwest',marker_color = '#000080'))
fig.add_trace(go.Scatter(x = auth_not_started.Date, y = auth_not_started['Mid West'], name = 'Midwest-line',mode = 'lines'))

fig.update_layout(title_text = 'Permits Authorized but Not Started',
                  title_x = 0.5,
                  
                  yaxis_title = 'Not Started in Thousands',
                  yaxis_range = [0,200],
                  yaxis_dtick = 10,
                  xaxis_title = 'Period By Quarter',
                  font = dict(family = 'verdana',
                             size = 12,
                             color = 'black',
                             ),
                  yaxis_showgrid = False,
                  yaxis_linecolor = 'white',
                  legend = dict(bgcolor ='white',
                                title = 'Legend',
                                font = dict(color = 'black',size = 8)
                               ),
                  plot_bgcolor = 'white',
                  clickmode = 'select',
                  dragmode = 'drawline',
                  transition = dict(duration = 1000,
                                   easing = 'bounce-in',
                                   ordering = 'traces first'))
                  
                  
fig.add_vrect(x0 = '2020-12-1', x1 = '2021-12-30', col =1, fillcolor="gray",opacity=0.15, line_width=0)

fig.show()
# Out:
# <div>                            <div id="b079e91d-7bfb-47d3-8e46-719661b09dfd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b079e91d-7bfb-47d3-8e46-719661b09dfd")) {                    Plotly.newPlot(                        "b079e91d-7bfb-47d3-8e46-719661b09dfd",                        [{"marker":{"color":"gray"},"name":"USA","x":["2014-01-01","2014-02-01","2014-03-01","2014-04-01","2014-05-01","2014-06-01","2014-07-01","2014-08-01","2014-09-01","2014-10-01","2014-11-01","2014-12-01","2015-01-01","2015-02-01","2015-03-01","2015-04-01","2015-05-01","2015-06-01","2015-07-01","2015-08-01","2015-09-01","2015-10-01","2015-11-01","2015-12-01","2016-01-01","2016-02-01","2016-03-01","2016-04-01","2016-05-01","2016-06-01","2016-07-01","2016-08-01","2016-
# ...

# %%
# USA_corr = auth_not_started[['Date','United States']]
# USA_corr['Date'] = pd.to_datetime(USA_corr['Date'])
# USA_corr.set_index('Date',inplace = True)
# South_corr = auth_not_started[['Date','South']]
# South_corr['Date'] = pd.to_datetime(South_corr['Date'])
# South_corr.set_index('Date',inplace = True)
# West_corr['Date'] = pd.to_datetime(West_corr['Date'])
# West_corr = auth_not_started[['Date','West']]
# West_corr.set_index('Date',inplace = True)

# %%
plot_acf(USA_corr,lags = 31)

# %%
plot_acf(West_corr, lags = 31)

# %%
plot_acf(South_corr, lags = 31)

# %%
ss = new_price_by_region.set_index('Region')

# %%
#sold_finance_type.reset_index(inplace = True)
#sold_finance_type.drop(['index', 'level_0'], inplace = True, axis = 1)
fig2 = go.Figure()
fig2.add_trace(go.Scatter(x = sold_finance_type.Period, y = sold_finance_type['Conventional'], name = 'Conventional',stackgroup='one'))
fig2.add_trace(go.Scatter(x = sold_finance_type.Period, y = sold_finance_type['FHA Insured'], name = 'FHA Insured',stackgroup='two'))
fig2.add_trace(go.Scatter(x = sold_finance_type.Period, y = sold_finance_type['VA Guaranteed'], name = 'VA Guaranteed',stackgroup='three'))
fig2.add_trace(go.Scatter(x = sold_finance_type.Period, y = sold_finance_type['Cash'], name = 'Cash',stackgroup='four'))
fig2.update_layout(title_text = 'Type of Financing (2014 - 2021)',
                  title_x = 0.5,
                  
                  yaxis_title = 'Count in Thousands',
                  yaxis_range = [0,250],
                  yaxis_dtick = 10,
                  xaxis_title = 'Period By Quarter',
                  font = dict(family = 'verdana',
                             size = 12,
                             color = 'black',
                             ),
                  yaxis_showgrid = False,
                  yaxis_linecolor = 'white',
                  legend = dict(bgcolor ='white',
                                title = 'Legend',
                                font = dict(color = 'black',size = 8)
                               ),
                  plot_bgcolor = 'white',
                  clickmode = 'select',
                  dragmode = 'drawline',
                  transition = dict(duration = 1000,
                                   easing = 'bounce-in',
                                   ordering = 'traces first'))

fig2.add_vrect(x0 = '2020Q4', x1 = '2021Q4', col =1, fillcolor="gray",opacity=0.25, line_width=0,annotation_text="steep decline")
# Out:
# <div>                            <div id="d8ac45c8-0abe-4eb9-9341-ee9eab4b785f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d8ac45c8-0abe-4eb9-9341-ee9eab4b785f")) {                    Plotly.newPlot(                        "d8ac45c8-0abe-4eb9-9341-ee9eab4b785f",                        [{"name":"Conventional","stackgroup":"one","x":["2014Q1","2014Q2","2014Q3","2014Q4","2015Q1","2015Q2","2015Q3","2015Q4","2016Q1","2016Q2","2016Q3","2016Q4","2017Q1","2017Q2","2017Q3","2017Q4","2018Q1","2018Q2","2018Q3","2018Q4","2019Q1","2019Q2","2019Q3","2019Q4","2020Q1","2020Q2","2020Q3","2020Q4","2021Q1","2021Q2","2021Q3","2021Q4"],"y":[76,83,78,76,91,95,83,79,93,108,106,89,113,121,104,104,124,134,108,94,120,125,117,107,125,131,172,139,163,148,131,123],"type":"
# ...

# %%
sold_finance_type
# Out:
#     Period  Total Sold  Total Sold Rate of Change  Conventional  \
# 0   2014Q1         106                        NaN            76
# 1   2014Q2         120                   0.132075            83
# 2   2014Q3         107                  -0.108333            78
# 3   2014Q4         104                  -0.028037            76
# 4   2015Q1         131                   0.259615            91
# 5   2015Q2         140                   0.068702            95
# 6   2015Q3         119                  -0.150000            83
# 7   2015Q4         112                  -0.058824            79
# 8   2016Q1         134                   0.196429            93
# 9   2016Q2         158                   0.179104           108
# 10  2016Q3         144                  -0.088608           106
# 11  2016Q4         125                  -0.131944            89
# 12  2017Q1         156                   0.248000           113
# 13  2017Q2         170                   0.089744           121
# ...

# %%
fig3 = make_subplots(rows=2, cols=2)
closer_look_finance= sold_finance_type.loc[20:31]
fig3.add_trace(go.Line(x = closer_look_finance.Period, y = closer_look_finance['Conventional'],name = 'Conventional'),row=1, col=1)
fig3.add_trace(go.Line(x = closer_look_finance.Period, y = closer_look_finance['FHA Insured'], name = 'FHA Insured Rate of Change'),row=1, col=2)
fig3.add_trace(go.Line(x = closer_look_finance.Period, y = closer_look_finance['VA Guaranteed'], name = 'VA Guaranteed'),row=2, col=1)
fig3.add_trace(go.Line(x = closer_look_finance.Period, y = closer_look_finance['Cash'], name = 'Cash'),row=2, col=2)



fig3.add_vrect(x0 = '2021Q1', x1 = '2021Q4', col =1, fillcolor="gray",opacity=0.25, line_width=0,annotation_text="steep decline",exclude_empty_subplots=False,)
fig3.add_vrect(x0 = '2021Q1', x1 = '2021Q4', col =2, fillcolor="gray",opacity=0.25, line_width=0,annotation_text="steep decline",exclude_empty_subplots=False)
# Out:
# <div>                            <div id="e316f03f-6e08-4a6b-8787-73b729f63c16" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e316f03f-6e08-4a6b-8787-73b729f63c16")) {                    Plotly.newPlot(                        "e316f03f-6e08-4a6b-8787-73b729f63c16",                        [{"name":"Conventional","x":["2019Q1","2019Q2","2019Q3","2019Q4","2020Q1","2020Q2","2020Q3","2020Q4","2021Q1","2021Q2","2021Q3","2021Q4"],"y":[120,125,117,107,125,131,172,139,163,148,131,123],"type":"scatter","xaxis":"x","yaxis":"y"},{"name":"FHA Insured Rate of Change","x":["2019Q1","2019Q2","2019Q3","2019Q4","2020Q1","2020Q2","2020Q3","2020Q4","2021Q1","2021Q2","2021Q3","2021Q4"],"y":[30,35,26,29,32,40,45,37,43,26,23,14],"type":"scatter","xaxis":"x2","yaxis":"y2
# ...

# %%
closer_look_finance
# Out:
#     Period  Total Sold  Total Sold Rate of Change  Conventional  \
# 20  2019Q1         174                   0.380952           120
# 21  2019Q2         186                   0.068966           125
# 22  2019Q3         168                  -0.096774           117
# 23  2019Q4         154                  -0.083333           107
# 24  2020Q1         181                   0.175325           125
# 25  2020Q2         196                   0.082873           131
# 26  2020Q3         243                   0.239796           172
# 27  2020Q4         202                  -0.168724           139
# 28  2021Q1         229                   0.133663           163
# 29  2021Q2         200                  -0.126638           148
# 30  2021Q3         175                  -0.125000           131
# 31  2021Q4         158                  -0.097143           123
#
#     Conventional Rate of Change  FHA Insured  FHA Insured Rate of Change  \
# ...
