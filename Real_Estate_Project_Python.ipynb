# %%
import pandas as pd
import numpy as np
import chart_studio.plotly as py
import seaborn as sns
import plotly.express as px
import cufflinks as cf
# %matplotlib inline
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
#init_notebook_mode(connected = True)
cf.go_offline()
import plotly.graph_objects as go
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
'''Setting option for pandas to show maximum rows and columns'''

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
'''
File 1 --> 'new_price_by_region' --> new houses sold in 4 regions based on price range of homes.
File 2 --> 'auth_not_started.csv' --> authorized permits but not yet started homes. 
File 3 --> 'sold_finance_type.csv' -- > the type if financing for a loan and the rate of change.
File 4 --> houses_sold_by_sales_price_USA.csv' -->New Houses sold in the USA based on price range.
File 5 --> 'construction_status_2021.csv' --> Construction status in the usa and regions in 2021. The status categories 
are [started, completed, under construction]. 

'''



#File 1
auth_not_started = pd.read_csv('auth_not_started.csv',index_col=0)

#File 2
new_price_by_region = pd.read_csv('new_price_by_region', index_col=0)

#File 3
sold_finance_type =  pd.read_csv('sold_finance_type.csv', index_col=0)

#File 4

by_sales_price_USA = pd.read_csv('houses_sold_by_sales_price_USA.csv', index_col = 0)

#File 5
status_2021 = pd.read_csv('construction_status_2021.csv', index_col = 0)

status_2021

#File 6 (For the future, I will explore micro trends in the construction industry to extrapolate strategies for 
#investors)
# Out:
# "\nFile 1 --> 'new_price_by_region' --> new houses sold in 4 regions based on price range of homes.\nFile 2 --> 'auth_not_started.csv' --> authorized permits but not yet started homes. \nFile 3 --> 'sold_finance_type.csv' -- > the type if financing for a loan and the rate of change.\nFile 4 --> houses_sold_by_sales_price_USA.csv' -->New Houses sold in the USA based on price range.\nFile 5 --> 'construction_status_2021.csv' --> Construction status in the usa and regions in 2021. The status categories \nare [started, completed, under construction]. \n\n\n"

# %%
# Out:
#              USA  NorthEast  Midwest  South   West                  Status  \
# Period
# January    597.3       56.6     83.5  296.6  160.6      Under Construction
# February   600.4       55.4     78.6  300.8  165.6      Under Construction
# March      619.0       56.1     84.1  307.9  170.9      Under Construction
# April      636.9       58.8     87.4  316.2  174.5      Under Construction
# May        657.9       59.8     95.1  322.7  180.4      Under Construction
# June       687.6       61.9     96.8  343.9  185.1      Under Construction
# July       714.2       61.2    101.9  361.6  189.5      Under Construction
# August     729.3       62.7    104.2  374.7  187.7      Under Construction
# September  741.9       63.8    105.8  380.7  191.6      Under Construction
# Octoberr   750.0       63.5    106.8  387.3  192.4      Under Construction
# Novemberr  760.7       64.0    104.9  397.7  194.1      Under Construction
# Decemberp  748.8       61.8    107.0  391.9  188.0      Under Construction
# January     72.2        5.4     10.0   41.8   15.1  Construction Completed
# February    72.5        4.1     10.2   41.0   17.3  Construction Completed
# March       83.9        6.1      9.4   50.4   17.9  Construction Completed
# April       78.9        3.4      9.6   45.9   20.0  Construction Completed
# May         80.3        4.0      9.7   47.5   19.1  Construction Completed
# June        80.9        6.5     11.8   40.8   21.8  Construction Completed
# July        78.5        4.9      9.8   43.2   20.6  Construction Completed
# August      83.0        5.1     10.0   47.0   20.9  Construction Completed
# September   79.0        4.8     11.3   44.3   18.6  Construction Completed
# Octoberr    83.0        4.8     11.7   43.5   23.0  Construction Completed
# Novemberr   78.7        4.7     11.9   42.6   19.5  Construction Completed
